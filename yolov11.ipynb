# %%
#this is to do training

from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s.pt")

# Train the model
train_results = model.train(
    data="C:/Users/User/data/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\User\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 18.4M/18.4M [00:05<00:00, 3.34MB/s]
# Ultralytics 8.3.112  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %%
#this is to do prediction on the test set images

# Load a model
model = YOLO("C:/Users/User/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("C:/Users/User/data/test/images", save=True)
# Out:
# image 1/23 C:\Users\User\data\test\images\1005_png.rf.a028d6867558e274105661138d311dda.jpg: 640x640 8 fishs, 12.3ms
# image 2/23 C:\Users\User\data\test\images\1007_png.rf.9d8fc7dd299b4201b12d7350c71591b4.jpg: 640x640 10 fishs, 13.0ms
# image 3/23 C:\Users\User\data\test\images\1029_png.rf.a9ff3c1f9252addbb69f8351da10c934.jpg: 640x640 10 fishs, 13.8ms
# image 4/23 C:\Users\User\data\test\images\1098_png.rf.d45882249c8ca53c61bb0c214bc81e59.jpg: 640x640 9 fishs, 12.7ms
# image 5/23 C:\Users\User\data\test\images\1112_png.rf.5efacaf7be331aadf3bba043e63ec759.jpg: 640x640 10 fishs, 13.4ms
# image 6/23 C:\Users\User\data\test\images\1125_png.rf.d2095e523bbf50e95ea31805c48dcefd.jpg: 640x640 9 fishs, 13.9ms
# image 7/23 C:\Users\User\data\test\images\1136_png.rf.f28524ec73a3e2ed686e1f6cddff561a.jpg: 640x640 9 fishs, 13.7ms
# image 8/23 C:\Users\User\data\test\images\1141_png.rf.f5509ea4e6cbe7ebe482df2574bd90e3.jpg: 640x640 8 fishs, 12.8ms
# ...

# %%
#this is to do prediction on video

# Load a model
model = YOLO("C:/Users/User/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("C:/Users/User/data/test/video", save=True)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/831) C:\Users\User\data\test\video\1.MP4: 384x640 27 fishs, 46.0ms
# video 1/1 (frame 2/831) C:\Users\User\data\test\video\1.MP4: 384x640 26 fishs, 10.9ms
# video 1/1 (frame 3/831) C:\Users\User\data\test\video\1.MP4: 384x640 25 fishs, 11.0ms
# video 1/1 (frame 4/831) C:\Users\User\data\test\video\1.MP4: 384x640 25 fishs, 10.4ms
# video 1/1 (frame 5/831) C:\Users\User\data\test\video\1.MP4: 384x640 28 fishs, 9.7ms
# ...

# %%
#this is to do validation on best trained model

from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s.pt")  # load an official model
model = YOLO("C:/Users/User/runs/detect/train/weights/best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.112  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 249.527.9 MB/s, size: 26.3 KB)
# val: Scanning C:\Users\User\data\valid\labels.cache... 34 images, 0 backgrounds, 0 corrupt: 100%|██████████| 34/34 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:12<00:00,  4.03s/it]
#                    all         34        431      0.911      0.948      0.968      0.612
# Speed: 27.0ms preprocess, 26.7ms inference, 0.0ms loss, 6.0ms postprocess per image
# Results saved to runs\detect\val2
# array([    0.61192])

# %%
#this is to find optimal threshold where i created confusion matrix with varying confidence

from ultralytics import YOLO

model = YOLO("C:/Users/User/runs/detect/train/weights/best.pt")

# Run validation with a custom confidence threshold
metrics = model.val(conf=0.90)  # Lower confidence to generate a complete F1 curve (vary it from 0.1-0.9)
# Out:
# Ultralytics 8.3.112  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 371.983.8 MB/s, size: 33.2 KB)
# val: Scanning C:\Users\User\data\valid\labels.cache... 34 images, 0 backgrounds, 0 corrupt: 100%|██████████| 34/34 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:07<00:00,  2.46s/it]
#                    all         34        431          1    0.00696      0.503      0.369
# Speed: 6.5ms preprocess, 15.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs\detect\val19
